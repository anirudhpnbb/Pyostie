# %%
import pyostie

# %%
output = pyostie.extract('/home/anirudhpnbb/Downloads/Patterson Invoice 1.pdf', insights=True, extension="pdf")

# %%
df, text = output.start()
# Out:
# pdf
# We are currently not generating insights for multi page pdf's, so returning only text. Please watch this space for updates.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b8f4a59ab09a> in <module>
# ----> 1 df, text = output.start()
#
# ValueError: too many values to unpack (expected 2)

# %%
df

# %%
import pandas as pd

# %%
a = pd.DataFrame([{"a":1, "b": 2}])

# %%
a
# Out:
#    a  b
# 0  1  2

# %%
c = [a]

# %%
c
# Out:
# [   a  b
#  0  1  2]

# %%
df = pd.read_excel("/home/anirudhpnbb/Projects/Intelytica/intelligent-recognition/output/anchor_columns_output/17_006Trimax_04_jpg_16042021_011634_anchor_columns_output.xlsx")

# %%
df = df.set_index('Unnamed: 0').T.to_dict('list')

# %%
df
# Out:
# {0: ['INTELYTICA',
#   'INTELYTICA',
#   0.959,
#   0,
#   nan,
#   nan,
#   0,
#   nan,
#   2200,
#   1700,
#   1,
#   '[1187, 196, 1385, 196, 1385, 224, 1187, 223]',
#   '[1189, 196, 1384, 197, 1384, 225, 1188, 224]',
#   '(1189, 196)',
#   '(1384, 197)',
#   '(1384, 225)',
#   '(1188, 224)',
#   24.06,
#   18.32,
#   21.29,
#   39.89,
#   24.06,
#   18.3,
#   21.29,
#   39.91,
#   3.7,
#   0.52,
#   3.67,
#   0.52,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
#   'XXXXXXXXXX',
#   'XXXXXXXXXX',
#   0,
#   'None',
#   0,
#   0],
#  1: ['Invoice',
#   'Invoice',
#   0.938,
#   1,
#   1.0,
#   2.0,
#   0,
#   nan,
#   2200,
#   1700,
#   1,
#   '[831, 362, 957, 362, 958, 395, 831, 396]',
#   '[833, 363, 958, 363, 958, 396, 832, 397]',
#   '(833, 363)',
#   '(958, 363)',
#   '(958, 396)',
#   '(832, 397)',
#   27.5,
#   15.82,
#   17.91,
#   42.39,
#   27.53,
#   15.78,
#   17.9,
#   42.43,
#   2.36,
#   0.64,
#   2.34,
#   0.62,
#   0,
#   0,
#   0,
#   0,
#   0,
#   0,
# ...

# %%
df = pd.DataFrame(df)

# %%
df
# Out:
#                                              0    \
# 0                                     INTELYTICA
# 1                                     INTELYTICA
# 2                                          0.959
# 3                                              0
# 4                                            NaN
# 5                                            NaN
# 6                                              0
# 7                                            NaN
# 8                                           2200
# 9                                           1700
# 10                                             1
# 11  [1187, 196, 1385, 196, 1385, 224, 1187, 223]
# 12  [1189, 196, 1384, 197, 1384, 225, 1188, 224]
# 13                                   (1189, 196)
# 14                                   (1384, 197)
# 15                                   (1384, 225)
# 16                                   (1188, 224)
# 17                                         24.06
# ...

# %%
c[0]
# Out:
#    a  b
# 0  1  2

# %%
text
